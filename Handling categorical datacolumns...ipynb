# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# %matplotlib inline

# %%
data=pd.read_csv("melb_data.csv")

# %%
data
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 0             Abbotsford         85 Turner St      2    h  1480000.0      S
# 1             Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 2             Abbotsford         5 Charles St      3    h  1465000.0     SP
# 3             Abbotsford     40 Federation La      3    h   850000.0     PI
# 4             Abbotsford          55a Park St      4    h  1600000.0     VB
# 5             Abbotsford       129 Charles St      2    h   941000.0      S
# 6             Abbotsford         124 Yarra St      3    h  1876000.0      S
# 7             Abbotsford        98 Charles St      2    h  1636000.0      S
# 8             Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 9             Abbotsford        10 Valiant St      2    h  1097000.0      S
# 10            Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# ...

# %%
x=data.drop('Price',axis=1)
y=data['Price']
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=0.2)

# %%
def get_mae(x_t,x_v,y_t,y_v):
    model=RandomForestRegressor(n_estimators=100,random_state=1).fit(x_t,y_t)
    p=model.predict(x_v)
    return mean_absolute_error(y_v,p)

# %% [markdown]
# # DEALING WITH CATEGORICAL COLUMNS DATa..

# %%
#method 1:-deleting OBJECT datatype columns...


reduced_x_train=x_train.select_dtypes(exclude="object")
reduced_x_test=x_test.select_dtypes(exclude="object")

##method 2 for removing NAN values....

from sklearn.impute import SimpleImputer

imp=SimpleImputer()

reduced1_x_train=pd.DataFrame(imp.fit_transform(reduced_x_train))
reduced1_x_test=pd.DataFrame(imp.transform(reduced_x_test))

#copying same set of columns names....
reduced1_x_train.columns=reduced_x_train.columns
reduced1_x_test.columns=reduced_x_test.columns

print("MAE: ",get_mae(reduced1_x_train,reduced1_x_test,y_train,y_test))
# Out:
# MAE:  166170.5766405428

# %%
##getting the list of object dtype columns....(actual)
object_cols=(x_train.dtypes=="object")
object_cols=list(object_cols[object_cols].index)
object_cols
# Out:
# ['Suburb',
#  'Address',
#  'Type',
#  'Method',
#  'SellerG',
#  'Date',
#  'CouncilArea',
#  'Regionname']

# %%
# "Cardinality" means the number of unique values in a column...(but considering according to cardinality)
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
low_cardinality_cols = [cname for cname in x_train.columns if x_train[cname].nunique() < 10 and 
                        x_train[cname].dtype == "object"]
low_cardinality_cols

# Select numerical columns
numerical_cols = [cname for cname in x_train.columns if x_train[cname].dtype in ['int64', 'float64']]


columns=low_cardinality_cols+numerical_cols

# %%
#method 2:- by LABELENCODER...
from sklearn.preprocessing import LabelEncoder

#make copy of original data...
reduced_x_train=x_train[columns].copy()
reduced_x_test=x_test[columns].copy()

model=LabelEncoder()
for cols in low_cardinality_cols:
    reduced_x_train[cols]=model.fit_transform(x_train[cols])
    reduced_x_test[cols]=model.transform(x_test[cols])

reduced_x_train.info()


##method 2 for removing NAN values....

from sklearn.impute import SimpleImputer

imp=SimpleImputer()

reduced1_x_train=pd.DataFrame(imp.fit_transform(reduced_x_train))
reduced1_x_test=pd.DataFrame(imp.transform(reduced_x_test))

#copying same set of columns names....
reduced1_x_train.columns=reduced_x_train.columns
reduced1_x_test.columns=reduced_x_test.columns

reduced1_x_train.isnull().sum()
print("MAE: ",get_mae(reduced1_x_train,reduced1_x_test,y_train,y_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10864 entries, 1041 to 13349
# Data columns (total 15 columns):
# Type             10864 non-null int32
# Method           10864 non-null int32
# Regionname       10864 non-null int32
# Rooms            10864 non-null int64
# Distance         10864 non-null float64
# Postcode         10864 non-null float64
# Bedroom2         10864 non-null float64
# Bathroom         10864 non-null float64
# Car              10812 non-null float64
# Landsize         10864 non-null float64
# BuildingArea     5671 non-null float64
# YearBuilt        6552 non-null float64
# Lattitude        10864 non-null float64
# Longtitude       10864 non-null float64
# Propertycount    10864 non-null float64
# dtypes: float64(11), int32(3), int64(1)
# memory usage: 1.2 MB
# MAE:  156589.58146416297

# %%
#from the above methods we can say that method 2 is the best way to deal with the catogorical data i.e LOCALENCODER...
